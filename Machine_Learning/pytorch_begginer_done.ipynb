# %% [markdown]
# ## Welcome to the beginner version of the UMARV 2024-2025 PyTorch coding checkpoint
#
# In this notebook you will be creating a basic CNN architecture that performormes image recognition. This will give you the necessary experience you need to get started designing models for the robot.
#
# # This should take around 1-3 hours
# You may look to Ryan or online resources for help if you want to meet this time. We suggest you stay away from AI tools because they will not help you learn the actual material and therefore hurting your ability to contribute to the actual robot. You are obviously welcome to go beyond this time to get more out of the checkpoint

# %% [markdown]
# # Step One
# Please download the dataset

# %%
#Do not adjust the imports unless you add additional functionality. These should be all that you need to complete the checkpoint
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
class CNN(nn.Module):
    def __init__(self, in_channels = 1, num_classes = 10):
        super(CNN, self).__init__()
        '''
        Network outline
        conv1 -> ReLU -> max pool -> conv2 -> ReLU -> max pool -> fully connected

        conv1: nn.Conv2d with these parameters: in_channels=1, out_channels=8, kernel_size=(3,3), stride=1, padding=1
        pool1: nn.MaxPool2d with these parameters: kernel_size=(2,2), stride=(2,2)
        conv2: nn.Conv2d with these parameters: in_channels=8, out_channels=16, kernel_size=(3,3), stride=1, padding=1
        pool2: nn.MaxPool2d with these parameters: kernel_size=(2,2), stride=(2,2)
        fully connection: nn.Linear with these parameters: in_features=16*7*7, out_features=num_classes

        Leave the ReLU parts for the forward function
        '''
        #TODO: use the outline above to create the layers of your convolutional neural network.
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=(3,3), stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=(2,2), stride=(2,2))        #only need one pooling layer because you can reuse them
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3,3), stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=(2,2), stride=(2,2))
        self.fc1 = nn.Linear(in_features=16*7*7, out_features=num_classes)

    def forward(self, x):
        '''
        In this forward function you will feed a datapoint through your network and return the value.
        The return value is a tensor (basically just an optimized list) with 10 probabilites each giving the chance that
        the datapoint is that class.

        For example: [0.1, 0.1, 0.4, 0.0, 0.0, 0.2, 0.0, 0.0, 0.1, 0.1] this would datapoint would be classified as a 2 becuase thats what index
        has the highest probability.


        '''
        # here is the first example of how to pass the datapoint x into a convolutional layer and then through a ReLU activation function.
        # TODO: Finish passing x through the neural network, making sure to go through each layer and activation function from the netowrk outline above.
        # Then return x
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)

        # Once you move into the the full connected part, you must reshape x by flattening all of the pixels
        # into a line so it can be fed through a fully connected layer. The line below does that for you.
        x = x.reshape(x.shape[0], -1)
        x = self.fc1(x)        #pass x through full connected layer

        return x

# %% [markdown]
# # Now lets load the data

# %%
# Here we load in the MNIST dataset and divide it into a large training dataset and a smaller testing dataset
test_dataset = datasets.MNIST(root='dataset/', train=False, transform=transforms.ToTensor(), download=True)
train_dataset = datasets.MNIST(root='dataset/', train=True, transform=transforms.ToTensor(), download=True) #To Tensor for effeciency

'''
A key part of a any neural network is a dataloader. These loaders will automatically grab batches of data from the dataset. You can iterate
through these dataloaders and therefore interate over your entire dataset in a very simple way.
'''
#TODO: define a variable called batch_size so that the loaders know how much data to grab at a time. A good place to start is 16, 32, or 64
batch_size = 16
#TODO: Replace the None with the names of the datasets you want to use for that loader and if you want to shuffle the data or not (choose one and adjust later)
train_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=None)
test_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=None)

# %%
#The line below should not be adjusted and simply detects if there is a usable GPU that can be used for training.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#TODO: Please set these two variables to some generic values to start
# Learning rate is how fast your model will learn. If its too high it will miss understand the data, and if its too low it wont learn quick enough. so start with something like 0.001 0.01
# num epochs should stay under 20 for the sake of time, plus you shouldnt need many more than that with because the dataset is pretty simple
learning_rate = 0.01
num_epochs = 15

#Here we are defining the model and moving it to the device we want.
model = CNN().to(device)

#You may also leave these alone
criterion = nn.CrossEntropyLoss() #criterion is the way that we will measure the accuracy of the model throughout training process. You may research CrossEntropy on your own if you want.
optimizer = optim.Adam(model.parameters(), lr=learning_rate) # Adam is an optimizer that will help the neural network learn over time and make minor adjustments to the network to predict better.

#This is the start of the training loop, the outer loop goes through the epochs and the inner loop uses the dataloader to split up the data into batches and process them seperately
for epoch in range(num_epochs):
    for batch_idx, (data, targets) in enumerate(train_loader):
        #Send data to the device you are using so that if you have a GPU you can use its optimization for faster training
        data = data.to(device=device)
        targets = targets.to(device=device)

        #TODO: There are five main steps to train any NN or CNN and you are to place them below. Each are one line.
        #TODO 1: feed the data through your model using the model variable that was defined earlier.
        outputs = model(data)

        #TODO 2: use the criterion variable to calculate the loss of the model. This means you must pass in the predicted values you just got and the target values given from the dataset.
        loss = criterion(outputs, targets)

        #TODO 3: Reset the gradient values of the optimizer using the zero_grad() function.
        optimizer.zero_grad()

        #TODO 4: Use the loss and .backward() function to perform backpropogation which will tell the network where is needs to imporove the most to make better predictions
        loss.backward()

        #TODO 5: Use the optimizer and the .step() function to update parameters in the network and hepfully improve the performance
        optimizer.step()

    print(f"Completed {epoch} epochs so far")
# Out:
# Completed 0 epochs so far
# Completed 1 epochs so far
# Completed 2 epochs so far
# Completed 3 epochs so far
# Completed 4 epochs so far
# Completed 5 epochs so far
# Completed 6 epochs so far
# Completed 7 epochs so far
# Completed 8 epochs so far
# Completed 9 epochs so far
# Completed 10 epochs so far
# Completed 11 epochs so far
# Completed 12 epochs so far
# Completed 13 epochs so far
# Completed 14 epochs so far

# %% [markdown]
# # Now Lets Evaluate the Model Accuracy

# %%
def check_accuracy(loader, model):
    if loader.dataset.train:
        print("checking accuracy on training data")
    else:
        print("checking accuracy on test data")

    num_correct = 0
    num_samples = 0
    model.eval()

    with torch.no_grad(): #using torch.no_grad() makes sure the network parameters are not changed while we evaluate it
        #TODO: use the loader to loop through the features (x) and labels (y)
        for x, y in loader:
            #Again moving the data to the correct device
            x = x.to(device=device)
            y = y.to(device=device)

            #TODO: feed the data through your newly trained model and set the predictions to a variable
            output= model(x)
            _ , predictions = torch.max(output, 1)
            #TODO: Now you should have a tensor that is x.shape[0] by 10 where each row represents a data point and each column is a class.
            # Every cell should be the probability that a certain data point is classified as the given class. So now use the .max function to find the highest probability class
            # for each data point. Try you best with this, there are multiple ways to go about it (some in one line and some in many more). If you have tried for a while, visit
            # HINT1 below for some help

            #TODO: calculate the number of correct predictions by comparing the predictions to the labels (y).
            num_correct += (predictions==y).sum().item()

            num_samples += predictions.size(0) #no need to adjust, this simply keeps track of how many samples we have evaluate thus far

            print(f"Got {num_correct} / {num_samples} with accuracy {float(num_correct)/float(num_samples)*100:.2f}")
    model.train()

check_accuracy(train_loader, model)
check_accuracy(test_loader, model)
# Out:
# checking accuracy on test data
# Got 15 / 16 with accuracy 93.75
# Got 31 / 32 with accuracy 96.88
# Got 46 / 48 with accuracy 95.83
# Got 62 / 64 with accuracy 96.88
# Got 77 / 80 with accuracy 96.25
# Got 93 / 96 with accuracy 96.88
# Got 109 / 112 with accuracy 97.32
# Got 125 / 128 with accuracy 97.66
# Got 141 / 144 with accuracy 97.92
# Got 157 / 160 with accuracy 98.12
# Got 173 / 176 with accuracy 98.30
# Got 189 / 192 with accuracy 98.44
# Got 205 / 208 with accuracy 98.56
# Got 221 / 224 with accuracy 98.66
# Got 237 / 240 with accuracy 98.75
# Got 253 / 256 with accuracy 98.83
# Got 269 / 272 with accuracy 98.90
# Got 285 / 288 with accuracy 98.96
# Got 301 / 304 with accuracy 99.01
# Got 317 / 320 with accuracy 99.06
# Got 333 / 336 with accuracy 99.11
# Got 348 / 352 with accuracy 98.86
# Got 364 / 368 with accuracy 98.91
# Got 380 / 384 with accuracy 98.96
# Got 396 / 400 with accuracy 99.00
# Got 412 / 416 with accuracy 99.04
# Got 427 / 432 with accuracy 98.84
# Got 443 / 448 with accuracy 98.88
# Got 459 / 464 with accuracy 98.92
# Got 475 / 480 with accuracy 98.96
# Got 491 / 496 with accuracy 98.99
# Got 507 / 512 with accuracy 99.02
# Got 523 / 528 with accuracy 99.05
# Got 539 / 544 with accuracy 99.08
# Got 555 / 560 with accuracy 99.11
# Got 571 / 576 with accuracy 99.13
# Got 586 / 592 with accuracy 98.99
# Got 602 / 608 with accuracy 99.01
# Got 618 / 624 with accuracy 99.04
# Got 634 / 640 with accuracy 99.06
# Got 649 / 656 with accuracy 98.93
# Got 665 / 672 with accuracy 98.96
# Got 681 / 688 with accuracy 98.98
# Got 697 / 704 with accuracy 99.01
# Got 713 / 720 with accuracy 99.03
# Got 728 / 736 with accuracy 98.91
# Got 744 / 752 with accuracy 98.94
# Got 760 / 768 with accuracy 98.96
# Got 776 / 784 with accuracy 98.98
# Got 792 / 800 with accuracy 99.00
# Got 808 / 816 with accuracy 99.02
# Got 824 / 832 with accuracy 99.04
# Got 840 / 848 with accuracy 99.06
# Got 856 / 864 with accuracy 99.07
# Got 872 / 880 with accuracy 99.09
# Got 888 / 896 with accuracy 99.11
# Got 904 / 912 with accuracy 99.12
# Got 920 / 928 with accuracy 99.14
# Got 936 / 944 with accuracy 99.15
# Got 952 / 960 with accuracy 99.17
# Got 968 / 976 with accuracy 99.18
# Got 984 / 992 with accuracy 99.19
# Got 1000 / 1008 with accuracy 99.21
# Got 1015 / 1024 with accuracy 99.12
# Got 1030 / 1040 with accuracy 99.04
# Got 1046 / 1056 with accuracy 99.05
# Got 1062 / 1072 with accuracy 99.07
# Got 1078 / 1088 with accuracy 99.08
# Got 1094 / 1104 with accuracy 99.09
# Got 1110 / 1120 with accuracy 99.11
# Got 1126 / 1136 with accuracy 99.12
# Got 1142 / 1152 with accuracy 99.13
# Got 1158 / 1168 with accuracy 99.14
# Got 1174 / 1184 with accuracy 99.16
# Got 1190 / 1200 with accuracy 99.17
# Got 1206 / 1216 with accuracy 99.18
# Got 1222 / 1232 with accuracy 99.19
# Got 1238 / 1248 with accuracy 99.20
# Got 1254 / 1264 with accuracy 99.21
# Got 1270 / 1280 with accuracy 99.22
# Got 1286 / 1296 with accuracy 99.23
# Got 1302 / 1312 with accuracy 99.24
# Got 1317 / 1328 with accuracy 99.17
# Got 1333 / 1344 with accuracy 99.18
# Got 1349 / 1360 with accuracy 99.19
# Got 1365 / 1376 with accuracy 99.20
# Got 1380 / 1392 with accuracy 99.14
# Got 1394 / 1408 with accuracy 99.01
# Got 1410 / 1424 with accuracy 99.02
# Got 1426 / 1440 with accuracy 99.03
# Got 1442 / 1456 with accuracy 99.04
# Got 1458 / 1472 with accuracy 99.05
# Got 1474 / 1488 with accuracy 99.06
# Got 1490 / 1504 with accuracy 99.07
# Got 1506 / 1520 with accuracy 99.08
# Got 1522 / 1536 with accuracy 99.09
# Got 1538 / 1552 with accuracy 99.10
# Got 1554 / 1568 with accuracy 99.11
# Got 1570 / 1584 with accuracy 99.12
# Got 1586 / 1600 with accuracy 99.12
# Got 1602 / 1616 with accuracy 99.13
# Got 1618 / 1632 with accuracy 99.14
# Got 1634 / 1648 with accuracy 99.15
# Got 1650 / 1664 with accuracy 99.16
# Got 1666 / 1680 with accuracy 99.17
# Got 1682 / 1696 with accuracy 99.17
# Got 1698 / 1712 with accuracy 99.18
# Got 1713 / 1728 with accuracy 99.13
# Got 1729 / 1744 with accuracy 99.14
# Got 1745 / 1760 with accuracy 99.15
# Got 1760 / 1776 with accuracy 99.10
# Got 1776 / 1792 with accuracy 99.11
# Got 1792 / 1808 with accuracy 99.12
# Got 1808 / 1824 with accuracy 99.12
# Got 1824 / 1840 with accuracy 99.13
# Got 1840 / 1856 with accuracy 99.14
# Got 1856 / 1872 with accuracy 99.15
# Got 1872 / 1888 with accuracy 99.15
# Got 1887 / 1904 with accuracy 99.11
# Got 1903 / 1920 with accuracy 99.11
# Got 1919 / 1936 with accuracy 99.12
# Got 1935 / 1952 with accuracy 99.13
# Got 1951 / 1968 with accuracy 99.14
# Got 1967 / 1984 with accuracy 99.14
# Got 1983 / 2000 with accuracy 99.15
# Got 1998 / 2016 with accuracy 99.11
# Got 2014 / 2032 with accuracy 99.11
# Got 2030 / 2048 with accuracy 99.12
# Got 2045 / 2064 with accuracy 99.08
# Got 2060 / 2080 with accuracy 99.04
# Got 2076 / 2096 with accuracy 99.05
# Got 2092 / 2112 with accuracy 99.05
# Got 2108 / 2128 with accuracy 99.06
# Got 2123 / 2144 with accuracy 99.02
# Got 2138 / 2160 with accuracy 98.98
# Got 2154 / 2176 with accuracy 98.99
# Got 2169 / 2192 with accuracy 98.95
# Got 7780 / 7840 with accuracy 99.23
# Got 7796 / 7856 with accuracy 99.24
# Got 7812 / 7872 with accuracy 99.24
# Got 7828 / 7888 with accuracy 99.24
# Got 7844 / 7904 with accuracy 99.24
# Got 7860 / 7920 with accuracy 99.24
# Got 7876 / 7936 with accuracy 99.24
# Got 7892 / 7952 with accuracy 99.25
# Got 7908 / 7968 with accuracy 99.25
# Got 7924 / 7984 with accuracy 99.25
# Got 7940 / 8000 with accuracy 99.25
# Got 7956 / 8016 with accuracy 99.25
# Got 7972 / 8032 with accuracy 99.25
# Got 7988 / 8048 with accuracy 99.25
# Got 8004 / 8064 with accuracy 99.26
# Got 8020 / 8080 with accuracy 99.26
# Got 8036 / 8096 with accuracy 99.26
# Got 8052 / 8112 with accuracy 99.26
# Got 8067 / 8128 with accuracy 99.25
# Got 8083 / 8144 with accuracy 99.25
# Got 8099 / 8160 with accuracy 99.25
# Got 8115 / 8176 with accuracy 99.25
# Got 8131 / 8192 with accuracy 99.26
# Got 8147 / 8208 with accuracy 99.26
# Got 8163 / 8224 with accuracy 99.26
# Got 8179 / 8240 with accuracy 99.26
# Got 8195 / 8256 with accuracy 99.26
# Got 8211 / 8272 with accuracy 99.26
# Got 8226 / 8288 with accuracy 99.25
# Got 8242 / 8304 with accuracy 99.25
# Got 8258 / 8320 with accuracy 99.25
# Got 8274 / 8336 with accuracy 99.26
# Got 8290 / 8352 with accuracy 99.26
# Got 8305 / 8368 with accuracy 99.25
# Got 8321 / 8384 with accuracy 99.25
# Got 8337 / 8400 with accuracy 99.25
# Got 8352 / 8416 with accuracy 99.24
# Got 8368 / 8432 with accuracy 99.24
# Got 8384 / 8448 with accuracy 99.24
# Got 8400 / 8464 with accuracy 99.24
# Got 8416 / 8480 with accuracy 99.25
# Got 8432 / 8496 with accuracy 99.25
# Got 8448 / 8512 with accuracy 99.25
# Got 8464 / 8528 with accuracy 99.25
# Got 8480 / 8544 with accuracy 99.25
# Got 8496 / 8560 with accuracy 99.25
# Got 8512 / 8576 with accuracy 99.25
# Got 8528 / 8592 with accuracy 99.26
# Got 8544 / 8608 with accuracy 99.26
# Got 8560 / 8624 with accuracy 99.26
# Got 8576 / 8640 with accuracy 99.26
# Got 8591 / 8656 with accuracy 99.25
# Got 8607 / 8672 with accuracy 99.25
# Got 8623 / 8688 with accuracy 99.25
# Got 8639 / 8704 with accuracy 99.25
# Got 8655 / 8720 with accuracy 99.25
# Got 8671 / 8736 with accuracy 99.26
# Got 8687 / 8752 with accuracy 99.26
# Got 8703 / 8768 with accuracy 99.26
# Got 8719 / 8784 with accuracy 99.26
# Got 8735 / 8800 with accuracy 99.26
# Got 8751 / 8816 with accuracy 99.26
# Got 8767 / 8832 with accuracy 99.26
# Got 8783 / 8848 with accuracy 99.27
# Got 8799 / 8864 with accuracy 99.27
# Got 8815 / 8880 with accuracy 99.27
# Got 8831 / 8896 with accuracy 99.27
# Got 8847 / 8912 with accuracy 99.27
# Got 8863 / 8928 with accuracy 99.27
# Got 8879 / 8944 with accuracy 99.27
# Got 8895 / 8960 with accuracy 99.27
# Got 1248 / 1296 with accuracy 96.30
# Got 1264 / 1312 with accuracy 96.34
# Got 1278 / 1328 with accuracy 96.23
# Got 1293 / 1344 with accuracy 96.21
# Got 1309 / 1360 with accuracy 96.25
# Got 1324 / 1376 with accuracy 96.22
# Got 1339 / 1392 with accuracy 96.19
# Got 1354 / 1408 with accuracy 96.16
# Got 1369 / 1424 with accuracy 96.14
# Got 1385 / 1440 with accuracy 96.18
# Got 1401 / 1456 with accuracy 96.22
# Got 1417 / 1472 with accuracy 96.26
# Got 1433 / 1488 with accuracy 96.30
# Got 1448 / 1504 with accuracy 96.28
# Got 1464 / 1520 with accuracy 96.32
# Got 1478 / 1536 with accuracy 96.22
# Got 1493 / 1552 with accuracy 96.20
# Got 1509 / 1568 with accuracy 96.24
# Got 1524 / 1584 with accuracy 96.21
# Got 1539 / 1600 with accuracy 96.19
# Got 1554 / 1616 with accuracy 96.16
# Got 1569 / 1632 with accuracy 96.14
# Got 1585 / 1648 with accuracy 96.18
# Got 1600 / 1664 with accuracy 96.15
# Got 1615 / 1680 with accuracy 96.13
# Got 1631 / 1696 with accuracy 96.17
# Got 1647 / 1712 with accuracy 96.20
# Got 1663 / 1728 with accuracy 96.24
# Got 1679 / 1744 with accuracy 96.27
# Got 1694 / 1760 with accuracy 96.25
# Got 1708 / 1776 with accuracy 96.17
# Got 1724 / 1792 with accuracy 96.21
# Got 1740 / 1808 with accuracy 96.24
# Got 1756 / 1824 with accuracy 96.27
# Got 1772 / 1840 with accuracy 96.30
# Got 1787 / 1856 with accuracy 96.28
# Got 1803 / 1872 with accuracy 96.31
# Got 1819 / 1888 with accuracy 96.35
# Got 1834 / 1904 with accuracy 96.32
# Got 1850 / 1920 with accuracy 96.35
# Got 1865 / 1936 with accuracy 96.33
# Got 1881 / 1952 with accuracy 96.36
# Got 1897 / 1968 with accuracy 96.39
# Got 1912 / 1984 with accuracy 96.37
# Got 1928 / 2000 with accuracy 96.40
# Got 1942 / 2016 with accuracy 96.33
# Got 1958 / 2032 with accuracy 96.36
# Got 1974 / 2048 with accuracy 96.39
# Got 1990 / 2064 with accuracy 96.41
# Got 2006 / 2080 with accuracy 96.44
# Got 2022 / 2096 with accuracy 96.47
# Got 2037 / 2112 with accuracy 96.45
# Got 2052 / 2128 with accuracy 96.43
# Got 2068 / 2144 with accuracy 96.46
# Got 2084 / 2160 with accuracy 96.48
# Got 2100 / 2176 with accuracy 96.51
# Got 2115 / 2192 with accuracy 96.49
# Got 2131 / 2208 with accuracy 96.51
# Got 2147 / 2224 with accuracy 96.54
# Got 2162 / 2240 with accuracy 96.52
# Got 2177 / 2256 with accuracy 96.50
# Got 2193 / 2272 with accuracy 96.52
# Got 2209 / 2288 with accuracy 96.55
# Got 2224 / 2304 with accuracy 96.53
# Got 2240 / 2320 with accuracy 96.55
# Got 2255 / 2336 with accuracy 96.53
# Got 2271 / 2352 with accuracy 96.56
# Got 2286 / 2368 with accuracy 96.54
# Got 2302 / 2384 with accuracy 96.56
# Got 2318 / 2400 with accuracy 96.58
# Got 2332 / 2416 with accuracy 96.52
# Got 4536 / 4688 with accuracy 96.76
# Got 4552 / 4704 with accuracy 96.77
# Got 4568 / 4720 with accuracy 96.78
# Got 4584 / 4736 with accuracy 96.79
# Got 4600 / 4752 with accuracy 96.80
# Got 4615 / 4768 with accuracy 96.79
# Got 4630 / 4784 with accuracy 96.78
# Got 4645 / 4800 with accuracy 96.77
# Got 4660 / 4816 with accuracy 96.76
# Got 4676 / 4832 with accuracy 96.77
# Got 4691 / 4848 with accuracy 96.76
# Got 4706 / 4864 with accuracy 96.75
# Got 4722 / 4880 with accuracy 96.76
# Got 4738 / 4896 with accuracy 96.77
# Got 4754 / 4912 with accuracy 96.78
# Got 4770 / 4928 with accuracy 96.79
# Got 4785 / 4944 with accuracy 96.78
# Got 4799 / 4960 with accuracy 96.75
# Got 4815 / 4976 with accuracy 96.76
# Got 4831 / 4992 with accuracy 96.77
# Got 4846 / 5008 with accuracy 96.77
# Got 4861 / 5024 with accuracy 96.76
# Got 4877 / 5040 with accuracy 96.77
# Got 4892 / 5056 with accuracy 96.76
# Got 4906 / 5072 with accuracy 96.73
# Got 4922 / 5088 with accuracy 96.74
# Got 4936 / 5104 with accuracy 96.71
# Got 4951 / 5120 with accuracy 96.70
# Got 4963 / 5136 with accuracy 96.63
# Got 4979 / 5152 with accuracy 96.64
# Got 4994 / 5168 with accuracy 96.63
# Got 5009 / 5184 with accuracy 96.62
# Got 5024 / 5200 with accuracy 96.62
# Got 5040 / 5216 with accuracy 96.63
# Got 5055 / 5232 with accuracy 96.62
# Got 5071 / 5248 with accuracy 96.63
# Got 5087 / 5264 with accuracy 96.64
# Got 5103 / 5280 with accuracy 96.65
# Got 5118 / 5296 with accuracy 96.64
# Got 5134 / 5312 with accuracy 96.65
# Got 5150 / 5328 with accuracy 96.66
# Got 5164 / 5344 with accuracy 96.63
# Got 5180 / 5360 with accuracy 96.64
# Got 5194 / 5376 with accuracy 96.61
# Got 5210 / 5392 with accuracy 96.62
# Got 5226 / 5408 with accuracy 96.63
# Got 5241 / 5424 with accuracy 96.63
# Got 5257 / 5440 with accuracy 96.64
# Got 5273 / 5456 with accuracy 96.65
# Got 5289 / 5472 with accuracy 96.66
# Got 5305 / 5488 with accuracy 96.67
# Got 5321 / 5504 with accuracy 96.68
# Got 5336 / 5520 with accuracy 96.67
# Got 5352 / 5536 with accuracy 96.68
# Got 5366 / 5552 with accuracy 96.65
# Got 5381 / 5568 with accuracy 96.64
# Got 5397 / 5584 with accuracy 96.65
# Got 5413 / 5600 with accuracy 96.66
# Got 5429 / 5616 with accuracy 96.67
# Got 5443 / 5632 with accuracy 96.64
# Got 5459 / 5648 with accuracy 96.65
# Got 5474 / 5664 with accuracy 96.65
# Got 5490 / 5680 with accuracy 96.65
# Got 5505 / 5696 with accuracy 96.65
# Got 5521 / 5712 with accuracy 96.66
# Got 5537 / 5728 with accuracy 96.67
# Got 5552 / 5744 with accuracy 96.66
# Got 5568 / 5760 with accuracy 96.67
# Got 5584 / 5776 with accuracy 96.68
# Got 5599 / 5792 with accuracy 96.67
# Got 6699 / 6928 with accuracy 96.69
# Got 6714 / 6944 with accuracy 96.69
# Got 6730 / 6960 with accuracy 96.70
# Got 6746 / 6976 with accuracy 96.70
# Got 6762 / 6992 with accuracy 96.71
# Got 6778 / 7008 with accuracy 96.72
# Got 6793 / 7024 with accuracy 96.71
# Got 6808 / 7040 with accuracy 96.70
# Got 6824 / 7056 with accuracy 96.71
# Got 6840 / 7072 with accuracy 96.72
# Got 6854 / 7088 with accuracy 96.70
# Got 6869 / 7104 with accuracy 96.69
# Got 6884 / 7120 with accuracy 96.69
# Got 6900 / 7136 with accuracy 96.69
# Got 6914 / 7152 with accuracy 96.67
# Got 6930 / 7168 with accuracy 96.68
# Got 6946 / 7184 with accuracy 96.69
# Got 6962 / 7200 with accuracy 96.69
# Got 6977 / 7216 with accuracy 96.69
# Got 6993 / 7232 with accuracy 96.70
# Got 7007 / 7248 with accuracy 96.67
# Got 7023 / 7264 with accuracy 96.68
# Got 7039 / 7280 with accuracy 96.69
# Got 7055 / 7296 with accuracy 96.70
# Got 7071 / 7312 with accuracy 96.70
# Got 7087 / 7328 with accuracy 96.71
# Got 7102 / 7344 with accuracy 96.70
# Got 7116 / 7360 with accuracy 96.68
# Got 7132 / 7376 with accuracy 96.69
# Got 7148 / 7392 with accuracy 96.70
# Got 7164 / 7408 with accuracy 96.71
# Got 7180 / 7424 with accuracy 96.71
# Got 7195 / 7440 with accuracy 96.71
# Got 7211 / 7456 with accuracy 96.71
# Got 7227 / 7472 with accuracy 96.72
# Got 7242 / 7488 with accuracy 96.71
# Got 7258 / 7504 with accuracy 96.72
# Got 7274 / 7520 with accuracy 96.73
# Got 7288 / 7536 with accuracy 96.71
# Got 7304 / 7552 with accuracy 96.72
# Got 7320 / 7568 with accuracy 96.72
# Got 7336 / 7584 with accuracy 96.73
# Got 7350 / 7600 with accuracy 96.71
# Got 7365 / 7616 with accuracy 96.70
# Got 7381 / 7632 with accuracy 96.71
# Got 7397 / 7648 with accuracy 96.72
# Got 7412 / 7664 with accuracy 96.71
# Got 7427 / 7680 with accuracy 96.71
# Got 7443 / 7696 with accuracy 96.71
# Got 7459 / 7712 with accuracy 96.72
# Got 7473 / 7728 with accuracy 96.70
# Got 7487 / 7744 with accuracy 96.68
# Got 7503 / 7760 with accuracy 96.69
# Got 7516 / 7776 with accuracy 96.66
# Got 7531 / 7792 with accuracy 96.65
# Got 7546 / 7808 with accuracy 96.64
# Got 7562 / 7824 with accuracy 96.65
# Got 7578 / 7840 with accuracy 96.66
# Got 7592 / 7856 with accuracy 96.64
# Got 7608 / 7872 with accuracy 96.65
# Got 7624 / 7888 with accuracy 96.65
# Got 7639 / 7904 with accuracy 96.65
# Got 7655 / 7920 with accuracy 96.65
# Got 7670 / 7936 with accuracy 96.65
# Got 7685 / 7952 with accuracy 96.64
# Got 7700 / 7968 with accuracy 96.64
# Got 7716 / 7984 with accuracy 96.64
# Got 7731 / 8000 with accuracy 96.64
# Got 7745 / 8016 with accuracy 96.62
# Got 7761 / 8032 with accuracy 96.63
# Got 7777 / 8048 with accuracy 96.63
# Got 7793 / 8064 with accuracy 96.64
# Got 7809 / 8080 with accuracy 96.65
# Got 7823 / 8096 with accuracy 96.63
# Got 7838 / 8112 with accuracy 96.62
# Got 7852 / 8128 with accuracy 96.60
# Got 7868 / 8144 with accuracy 96.61
# Got 7884 / 8160 with accuracy 96.62
# Got 7899 / 8176 with accuracy 96.61
# Got 7914 / 8192 with accuracy 96.61
# Got 7928 / 8208 with accuracy 96.59
# Got 7942 / 8224 with accuracy 96.57
# Got 7957 / 8240 with accuracy 96.57
# Got 7973 / 8256 with accuracy 96.57
# Got 7988 / 8272 with accuracy 96.57
# Got 8004 / 8288 with accuracy 96.57
# Got 8020 / 8304 with accuracy 96.58
# Got 8036 / 8320 with accuracy 96.59
# Got 8052 / 8336 with accuracy 96.59
# Got 8067 / 8352 with accuracy 96.59
# Got 8083 / 8368 with accuracy 96.59
# Got 8099 / 8384 with accuracy 96.60
# Got 8114 / 8400 with accuracy 96.60
# Got 8128 / 8416 with accuracy 96.58
# Got 8143 / 8432 with accuracy 96.57
# Got 8158 / 8448 with accuracy 96.57
# Got 8174 / 8464 with accuracy 96.57
# Got 8188 / 8480 with accuracy 96.56
# Got 8203 / 8496 with accuracy 96.55
# Got 8218 / 8512 with accuracy 96.55
# Got 8233 / 8528 with accuracy 96.54
# Got 8248 / 8544 with accuracy 96.54
# Got 8263 / 8560 with accuracy 96.53
# Got 8279 / 8576 with accuracy 96.54
# Got 8295 / 8592 with accuracy 96.54
# Got 8310 / 8608 with accuracy 96.54
# Got 8325 / 8624 with accuracy 96.53
# Got 8340 / 8640 with accuracy 96.53
# Got 8356 / 8656 with accuracy 96.53
# Got 8372 / 8672 with accuracy 96.54
# Got 8386 / 8688 with accuracy 96.52
# Got 8400 / 8704 with accuracy 96.51
# Got 8411 / 8720 with accuracy 96.46
# Got 8426 / 8736 with accuracy 96.45
# Got 8442 / 8752 with accuracy 96.46
# Got 8454 / 8768 with accuracy 96.42
# Got 8469 / 8784 with accuracy 96.41
# Got 8483 / 8800 with accuracy 96.40
# Got 8499 / 8816 with accuracy 96.40
# Got 8515 / 8832 with accuracy 96.41
# Got 8530 / 8848 with accuracy 96.41
# Got 8543 / 8864 with accuracy 96.38
# Got 8557 / 8880 with accuracy 96.36
# Got 8570 / 8896 with accuracy 96.34
# Got 8585 / 8912 with accuracy 96.33
# Got 8600 / 8928 with accuracy 96.33
# Got 8615 / 8944 with accuracy 96.32
# Got 8630 / 8960 with accuracy 96.32
# Got 8645 / 8976 with accuracy 96.31
# Got 8660 / 8992 with accuracy 96.31
# Got 8676 / 9008 with accuracy 96.31
# Got 8691 / 9024 with accuracy 96.31
# Got 8707 / 9040 with accuracy 96.32
# Got 8723 / 9056 with accuracy 96.32
# Got 8739 / 9072 with accuracy 96.33
# Got 8755 / 9088 with accuracy 96.34
# Got 8770 / 9104 with accuracy 96.33
# Got 8786 / 9120 with accuracy 96.34
# Got 8802 / 9136 with accuracy 96.34
# Got 8817 / 9152 with accuracy 96.34
# Got 8833 / 9168 with accuracy 96.35
# Got 9925 / 10304 with accuracy 96.32
# Got 9941 / 10320 with accuracy 96.33
# Got 9957 / 10336 with accuracy 96.33
# Got 9973 / 10352 with accuracy 96.34
# Got 9989 / 10368 with accuracy 96.34
# Got 10005 / 10384 with accuracy 96.35
# Got 10021 / 10400 with accuracy 96.36
# Got 10035 / 10416 with accuracy 96.34
# Got 10051 / 10432 with accuracy 96.35
# Got 10067 / 10448 with accuracy 96.35
# Got 10083 / 10464 with accuracy 96.36
# Got 10099 / 10480 with accuracy 96.36
# Got 10115 / 10496 with accuracy 96.37
# Got 10131 / 10512 with accuracy 96.38
# Got 10147 / 10528 with accuracy 96.38
# Got 10163 / 10544 with accuracy 96.39
# Got 10179 / 10560 with accuracy 96.39
# Got 10195 / 10576 with accuracy 96.40
# Got 10210 / 10592 with accuracy 96.39
# Got 10226 / 10608 with accuracy 96.40
# Got 10242 / 10624 with accuracy 96.40
# Got 10258 / 10640 with accuracy 96.41
# Got 10273 / 10656 with accuracy 96.41
# Got 10289 / 10672 with accuracy 96.41
# Got 10304 / 10688 with accuracy 96.41
# Got 10320 / 10704 with accuracy 96.41
# Got 10336 / 10720 with accuracy 96.42
# Got 10352 / 10736 with accuracy 96.42
# Got 10367 / 10752 with accuracy 96.42
# Got 10382 / 10768 with accuracy 96.42
# Got 10398 / 10784 with accuracy 96.42
# Got 10414 / 10800 with accuracy 96.43
# Got 10430 / 10816 with accuracy 96.43
# Got 10446 / 10832 with accuracy 96.44
# Got 10462 / 10848 with accuracy 96.44
# Got 10476 / 10864 with accuracy 96.43
# Got 10492 / 10880 with accuracy 96.43
# Got 10507 / 10896 with accuracy 96.43
# Got 10523 / 10912 with accuracy 96.44
# Got 10539 / 10928 with accuracy 96.44
# Got 10555 / 10944 with accuracy 96.45
# Got 10571 / 10960 with accuracy 96.45
# Got 10587 / 10976 with accuracy 96.46
# Got 10602 / 10992 with accuracy 96.45
# Got 10615 / 11008 with accuracy 96.43
# Got 10631 / 11024 with accuracy 96.44
# Got 10646 / 11040 with accuracy 96.43
# Got 10662 / 11056 with accuracy 96.44
# Got 10678 / 11072 with accuracy 96.44
# Got 10693 / 11088 with accuracy 96.44
# Got 10709 / 11104 with accuracy 96.44
# Got 10725 / 11120 with accuracy 96.45
# Got 10739 / 11136 with accuracy 96.43
# Got 10755 / 11152 with accuracy 96.44
# Got 10771 / 11168 with accuracy 96.45
# Got 10787 / 11184 with accuracy 96.45
# Got 10802 / 11200 with accuracy 96.45
# Got 10816 / 11216 with accuracy 96.43
# Got 10832 / 11232 with accuracy 96.44
# Got 10848 / 11248 with accuracy 96.44
# Got 10864 / 11264 with accuracy 96.45
# Got 10880 / 11280 with accuracy 96.45
# Got 10895 / 11296 with accuracy 96.45
# Got 10911 / 11312 with accuracy 96.46
# Got 10927 / 11328 with accuracy 96.46
# Got 10943 / 11344 with accuracy 96.47
# ...
# Got 51415 / 53280 with accuracy 96.50
# Got 51431 / 53296 with accuracy 96.50
# Got 51447 / 53312 with accuracy 96.50
# Got 51462 / 53328 with accuracy 96.50
# Got 51478 / 53344 with accuracy 96.50
# Got 51494 / 53360 with accuracy 96.50
# Got 51510 / 53376 with accuracy 96.50
# Got 51526 / 53392 with accuracy 96.51
# Got 51540 / 53408 with accuracy 96.50
# Got 51556 / 53424 with accuracy 96.50
# Got 51572 / 53440 with accuracy 96.50
# Got 51588 / 53456 with accuracy 96.51
# Got 51604 / 53472 with accuracy 96.51
# Got 51620 / 53488 with accuracy 96.51
# Got 51635 / 53504 with accuracy 96.51
# Got 51651 / 53520 with accuracy 96.51
# Got 51666 / 53536 with accuracy 96.51
# Got 51682 / 53552 with accuracy 96.51
# Got 51697 / 53568 with accuracy 96.51
# Got 51712 / 53584 with accuracy 96.51
# Got 51727 / 53600 with accuracy 96.51
# Got 51743 / 53616 with accuracy 96.51
# Got 51759 / 53632 with accuracy 96.51
# Got 51774 / 53648 with accuracy 96.51
# Got 51790 / 53664 with accuracy 96.51
# Got 51806 / 53680 with accuracy 96.51
# Got 51822 / 53696 with accuracy 96.51
# Got 51838 / 53712 with accuracy 96.51
# Got 51853 / 53728 with accuracy 96.51
# Got 51866 / 53744 with accuracy 96.51
# Got 51882 / 53760 with accuracy 96.51
# Got 51898 / 53776 with accuracy 96.51
# Got 51914 / 53792 with accuracy 96.51
# Got 51928 / 53808 with accuracy 96.51
# Got 51944 / 53824 with accuracy 96.51
# Got 51958 / 53840 with accuracy 96.50
# Got 51972 / 53856 with accuracy 96.50
# Got 51988 / 53872 with accuracy 96.50
# Got 52001 / 53888 with accuracy 96.50
# Got 52017 / 53904 with accuracy 96.50
# Got 52032 / 53920 with accuracy 96.50
# Got 52048 / 53936 with accuracy 96.50
# Got 52063 / 53952 with accuracy 96.50
# Got 52079 / 53968 with accuracy 96.50
# Got 52092 / 53984 with accuracy 96.50
# Got 52106 / 54000 with accuracy 96.49
# Got 52122 / 54016 with accuracy 96.49
# Got 52138 / 54032 with accuracy 96.49
# Got 52154 / 54048 with accuracy 96.50
# Got 52170 / 54064 with accuracy 96.50
# Got 52185 / 54080 with accuracy 96.50
# Got 52200 / 54096 with accuracy 96.50
# Got 52216 / 54112 with accuracy 96.50
# Got 52232 / 54128 with accuracy 96.50
# Got 52248 / 54144 with accuracy 96.50
# Got 52264 / 54160 with accuracy 96.50
# Got 52280 / 54176 with accuracy 96.50
# Got 52296 / 54192 with accuracy 96.50
# Got 52311 / 54208 with accuracy 96.50
# Got 52327 / 54224 with accuracy 96.50
# Got 52343 / 54240 with accuracy 96.50
# Got 52359 / 54256 with accuracy 96.50
# Got 52375 / 54272 with accuracy 96.50
# Got 52390 / 54288 with accuracy 96.50
# Got 52405 / 54304 with accuracy 96.50
# Got 52420 / 54320 with accuracy 96.50
# Got 52436 / 54336 with accuracy 96.50
# Got 52452 / 54352 with accuracy 96.50
# Got 52468 / 54368 with accuracy 96.51
# Got 52484 / 54384 with accuracy 96.51
# Got 52499 / 54400 with accuracy 96.51
# Got 52514 / 54416 with accuracy 96.50
# Got 52530 / 54432 with accuracy 96.51
# Got 52546 / 54448 with accuracy 96.51
# Got 52561 / 54464 with accuracy 96.51
# Got 52577 / 54480 with accuracy 96.51
# Got 52593 / 54496 with accuracy 96.51
# Got 52609 / 54512 with accuracy 96.51
# Got 52625 / 54528 with accuracy 96.51
# Got 52640 / 54544 with accuracy 96.51
# Got 52655 / 54560 with accuracy 96.51
# Got 52671 / 54576 with accuracy 96.51
# Got 52684 / 54592 with accuracy 96.50
# Got 52700 / 54608 with accuracy 96.51
# Got 52716 / 54624 with accuracy 96.51
# Got 52732 / 54640 with accuracy 96.51
# Got 52748 / 54656 with accuracy 96.51
# Got 52764 / 54672 with accuracy 96.51
# Got 52780 / 54688 with accuracy 96.51
# Got 52796 / 54704 with accuracy 96.51
# Got 52812 / 54720 with accuracy 96.51
# Got 52827 / 54736 with accuracy 96.51
# Got 52842 / 54752 with accuracy 96.51
# Got 52857 / 54768 with accuracy 96.51
# Got 52873 / 54784 with accuracy 96.51
# Got 52888 / 54800 with accuracy 96.51
# Got 52904 / 54816 with accuracy 96.51
# Got 52920 / 54832 with accuracy 96.51
# Got 52935 / 54848 with accuracy 96.51
# Got 52948 / 54864 with accuracy 96.51
# Got 52962 / 54880 with accuracy 96.51
# Got 52976 / 54896 with accuracy 96.50
# Got 52990 / 54912 with accuracy 96.50
# Got 53005 / 54928 with accuracy 96.50
# Got 53019 / 54944 with accuracy 96.50
# Got 53034 / 54960 with accuracy 96.50
# Got 53048 / 54976 with accuracy 96.49
# Got 53064 / 54992 with accuracy 96.49
# Got 53080 / 55008 with accuracy 96.50
# Got 53095 / 55024 with accuracy 96.49
# Got 53110 / 55040 with accuracy 96.49
# Got 53126 / 55056 with accuracy 96.49
# Got 53142 / 55072 with accuracy 96.50
# Got 53158 / 55088 with accuracy 96.50
# Got 53174 / 55104 with accuracy 96.50
# Got 53190 / 55120 with accuracy 96.50
# Got 53206 / 55136 with accuracy 96.50
# Got 53221 / 55152 with accuracy 96.50
# Got 53235 / 55168 with accuracy 96.50
# Got 53251 / 55184 with accuracy 96.50
# Got 53266 / 55200 with accuracy 96.50
# Got 53281 / 55216 with accuracy 96.50
# Got 53296 / 55232 with accuracy 96.49
# Got 53312 / 55248 with accuracy 96.50
# Got 53328 / 55264 with accuracy 96.50
# Got 53344 / 55280 with accuracy 96.50
# Got 53360 / 55296 with accuracy 96.50
# Got 53376 / 55312 with accuracy 96.50
# Got 53392 / 55328 with accuracy 96.50
# Got 53406 / 55344 with accuracy 96.50
# Got 53422 / 55360 with accuracy 96.50
# Got 53436 / 55376 with accuracy 96.50
# Got 53452 / 55392 with accuracy 96.50
# Got 53467 / 55408 with accuracy 96.50
# Got 53483 / 55424 with accuracy 96.50
# Got 53498 / 55440 with accuracy 96.50
# Got 53514 / 55456 with accuracy 96.50
# Got 53530 / 55472 with accuracy 96.50
# Got 53546 / 55488 with accuracy 96.50
# Got 53562 / 55504 with accuracy 96.50
# Got 53577 / 55520 with accuracy 96.50
# Got 53592 / 55536 with accuracy 96.50
# Got 53608 / 55552 with accuracy 96.50
# Got 53623 / 55568 with accuracy 96.50
# Got 53639 / 55584 with accuracy 96.50
# Got 53652 / 55600 with accuracy 96.50
# Got 53667 / 55616 with accuracy 96.50
# Got 53682 / 55632 with accuracy 96.49
# Got 53698 / 55648 with accuracy 96.50
# Got 53714 / 55664 with accuracy 96.50
# Got 53730 / 55680 with accuracy 96.50
# Got 53745 / 55696 with accuracy 96.50
# Got 53761 / 55712 with accuracy 96.50
# Got 53777 / 55728 with accuracy 96.50
# Got 53793 / 55744 with accuracy 96.50
# Got 53808 / 55760 with accuracy 96.50
# Got 53824 / 55776 with accuracy 96.50
# Got 53839 / 55792 with accuracy 96.50
# Got 53853 / 55808 with accuracy 96.50
# Got 53869 / 55824 with accuracy 96.50
# Got 53884 / 55840 with accuracy 96.50
# Got 53900 / 55856 with accuracy 96.50
# Got 53916 / 55872 with accuracy 96.50
# Got 53931 / 55888 with accuracy 96.50
# Got 53946 / 55904 with accuracy 96.50
# Got 53961 / 55920 with accuracy 96.50
# Got 53977 / 55936 with accuracy 96.50
# Got 53993 / 55952 with accuracy 96.50
# Got 54008 / 55968 with accuracy 96.50
# Got 54024 / 55984 with accuracy 96.50
# Got 54040 / 56000 with accuracy 96.50
# Got 54055 / 56016 with accuracy 96.50
# Got 54071 / 56032 with accuracy 96.50
# Got 54087 / 56048 with accuracy 96.50
# Got 54102 / 56064 with accuracy 96.50
# Got 54118 / 56080 with accuracy 96.50
# Got 54134 / 56096 with accuracy 96.50
# Got 54150 / 56112 with accuracy 96.50
# Got 54166 / 56128 with accuracy 96.50
# Got 54181 / 56144 with accuracy 96.50
# Got 54197 / 56160 with accuracy 96.50
# Got 54213 / 56176 with accuracy 96.51
# Got 54229 / 56192 with accuracy 96.51
# Got 54245 / 56208 with accuracy 96.51
# Got 54260 / 56224 with accuracy 96.51
# Got 54276 / 56240 with accuracy 96.51
# Got 54292 / 56256 with accuracy 96.51
# Got 54308 / 56272 with accuracy 96.51
# Got 54324 / 56288 with accuracy 96.51
# Got 54339 / 56304 with accuracy 96.51
# Got 54355 / 56320 with accuracy 96.51
# Got 54371 / 56336 with accuracy 96.51
# Got 54387 / 56352 with accuracy 96.51
# Got 54403 / 56368 with accuracy 96.51
# Got 54417 / 56384 with accuracy 96.51
# Got 54432 / 56400 with accuracy 96.51
# Got 54448 / 56416 with accuracy 96.51
# Got 54464 / 56432 with accuracy 96.51
# Got 54480 / 56448 with accuracy 96.51
# Got 54495 / 56464 with accuracy 96.51
# Got 54511 / 56480 with accuracy 96.51
# Got 54526 / 56496 with accuracy 96.51
# Got 54541 / 56512 with accuracy 96.51
# Got 54557 / 56528 with accuracy 96.51
# Got 54573 / 56544 with accuracy 96.51
# Got 54589 / 56560 with accuracy 96.52
# Got 54603 / 56576 with accuracy 96.51
# Got 54618 / 56592 with accuracy 96.51
# Got 54633 / 56608 with accuracy 96.51
# Got 54648 / 56624 with accuracy 96.51
# Got 54664 / 56640 with accuracy 96.51
# Got 54679 / 56656 with accuracy 96.51
# Got 54694 / 56672 with accuracy 96.51
# Got 54710 / 56688 with accuracy 96.51
# Got 54726 / 56704 with accuracy 96.51
# Got 54742 / 56720 with accuracy 96.51
# Got 56933 / 58976 with accuracy 96.54
# Got 56949 / 58992 with accuracy 96.54
# Got 56965 / 59008 with accuracy 96.54
# Got 56981 / 59024 with accuracy 96.54
# Got 56997 / 59040 with accuracy 96.54
# Got 57013 / 59056 with accuracy 96.54
# Got 57029 / 59072 with accuracy 96.54
# Got 57045 / 59088 with accuracy 96.54
# Got 57061 / 59104 with accuracy 96.54
# Got 57077 / 59120 with accuracy 96.54
# Got 57093 / 59136 with accuracy 96.55
# Got 57109 / 59152 with accuracy 96.55
# Got 57125 / 59168 with accuracy 96.55
# Got 57141 / 59184 with accuracy 96.55
# Got 57157 / 59200 with accuracy 96.55
# Got 57173 / 59216 with accuracy 96.55
# Got 57189 / 59232 with accuracy 96.55
# Got 57205 / 59248 with accuracy 96.55
# Got 57221 / 59264 with accuracy 96.55
# Got 57237 / 59280 with accuracy 96.55
# Got 57252 / 59296 with accuracy 96.55
# Got 57266 / 59312 with accuracy 96.55
# Got 57282 / 59328 with accuracy 96.55
# Got 57297 / 59344 with accuracy 96.55
# Got 57313 / 59360 with accuracy 96.55
# Got 57327 / 59376 with accuracy 96.55
# Got 57342 / 59392 with accuracy 96.55
# Got 57358 / 59408 with accuracy 96.55
# Got 57374 / 59424 with accuracy 96.55
# Got 57390 / 59440 with accuracy 96.55
# Got 57406 / 59456 with accuracy 96.55
# Got 57421 / 59472 with accuracy 96.55
# Got 57437 / 59488 with accuracy 96.55
# Got 57453 / 59504 with accuracy 96.55
# Got 57469 / 59520 with accuracy 96.55
# Got 57485 / 59536 with accuracy 96.56
# Got 57501 / 59552 with accuracy 96.56
# Got 57517 / 59568 with accuracy 96.56
# Got 57533 / 59584 with accuracy 96.56
# Got 57549 / 59600 with accuracy 96.56
# Got 57564 / 59616 with accuracy 96.56
# Got 57580 / 59632 with accuracy 96.56
# Got 57596 / 59648 with accuracy 96.56
# Got 57612 / 59664 with accuracy 96.56
# Got 57628 / 59680 with accuracy 96.56
# Got 57644 / 59696 with accuracy 96.56
# Got 57659 / 59712 with accuracy 96.56
# Got 57672 / 59728 with accuracy 96.56
# Got 57687 / 59744 with accuracy 96.56
# Got 57703 / 59760 with accuracy 96.56
# Got 57719 / 59776 with accuracy 96.56
# Got 57735 / 59792 with accuracy 96.56
# Got 57751 / 59808 with accuracy 96.56
# Got 57767 / 59824 with accuracy 96.56
# Got 57781 / 59840 with accuracy 96.56
# Got 57797 / 59856 with accuracy 96.56
# Got 57813 / 59872 with accuracy 96.56
# Got 57829 / 59888 with accuracy 96.56
# Got 57845 / 59904 with accuracy 96.56
# Got 57860 / 59920 with accuracy 96.56
# Got 57876 / 59936 with accuracy 96.56
# Got 57891 / 59952 with accuracy 96.56
# Got 57907 / 59968 with accuracy 96.56
# Got 57922 / 59984 with accuracy 96.56
# Got 57938 / 60000 with accuracy 96.56

# %% [markdown]
# # Hints
# These should be used if you are unsure how to move forward on this checkpoint. These will not address all issues so feel free to ask Ryan or Matt if you are struggling with something beyond the Hints.

# %%
#HINT1: assuming scores is your model output tensor with the probabilities. you may use the max function like this: scores.max(some_parameter)
